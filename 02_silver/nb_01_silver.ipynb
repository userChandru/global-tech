# %%
# %sql
CREATE SCHEMA IF NOT EXISTS 02_global_tech_silver.transformed_tables;

# %%
comp_df = spark.table("01_global_tech_bronze.raw_files.company_raw")
comp_df.write.format("delta").mode("overwrite").saveAsTable(f"02_global_tech_silver.transformed_tables.transformed_company")
